# %%
# %%writefile  runExtractFranceSamples1-ipynbInTerminal.py
# 重新优化

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import matplotlib
from matplotlib.animation import FFMpegWriter
import string
from copy import deepcopy
import warnings
warnings.filterwarnings('ignore')

###################################################################################################
# 生成样本需要vehInOneLane,只考虑本车道的车


def genSamples(vehInOneEdge, redVehs, speedFlagDict, vehInOneLane):

    samplesAll = []  # 收集当前车道内对应红车所有样本

    for iRed, redID in enumerate(redVehs.vehicle_id.unique()):
        print("genSamples", iRed, redID)

        # 首先提取整个edge上的红车持续时间
        # 红灯状态的车辆ID，注意这个redVehs是在整个edge的
        redVehFocusTmp = redVehs[redVehs.vehicle_id == redID]
        timeList = redVehFocusTmp.timestep_time.values

        vehInOneEdge = vehInOneEdge.sort_values(
            by='timestep_time', ascending=True)  # 提取持续的时间段
        maxLanePos1 = max(vehInOneEdge.vehicle_pos)  # 车道的长度

        vehInOneLane = vehInOneLane.sort_values(
            by='timestep_time', ascending=True)  # 提取持续的时间段
        maxLanePos = max(vehInOneLane.vehicle_pos)  # 车道的长度

        if(max(timeList) - min(timeList)) < 3:
            print(" redID:", redID, "  (max(timeList) - min(timeList))<3")
            continue

        if(maxLanePos1 != maxLanePos):
            print(" redID:", redID, "  maxLanePos1 != maxLanePos",
                  maxLanePos1, maxLanePos)

        for t in timeList:  # 枚举红灯状态下的每个时间的每一辆车 ，注意不是在一个edge上，是在一条lane

            # 注意不是在一个edge上，是在一条lane
            locTmp1 = vehInOneLane.timestep_time == t
            # 距离红灯100米以内
            locTmp2 = (maxLanePos - vehInOneLane.vehicle_pos) < 100
            vehsAtTime = vehInOneLane[locTmp1 & locTmp2]  # 符合车道，时间和距离限制

            if len(vehsAtTime.vehicle_id.unique()) == 1:  # 如果当前时间车辆只有一部车，统计忽略
                #print("time",t,"len(vehsAtTime.vehicle_id.unique()) == 1")
                continue

            vehsAtTime = vehsAtTime.sort_values(
                by='vehicle_pos', ascending=False)
            counter = 0

            # 枚举当前道路上红灯状态下的每个时间的每一辆车，并生成每个时刻样本
            recordPerVeh = []  # 记录每一辆车的[位置和速度]

            for rowindex, veh in vehsAtTime.iterrows():  # 每一辆车
                vehX = veh.vehicle_x
                vehY = veh.vehicle_y
                vehVel = veh.vehicle_speed
                vehTime = veh.timestep_time
                vehID = veh.vehicle_id
                vehicle_Red_distane = maxLanePos - veh.vehicle_pos
                vehLaneID = veh.vehicle_lane
                #print("vehID:",vehID," vehicle_Red_distane:",vehicle_Red_distane)

                # if counter == 0 and vehID != redID:
                # 第一部车不是红灯静止车，有错误
                #print("counter == 0 and vehID != redID:",vehID,redID)
                # break

                recordPerVeh.extend(
                    [vehicle_Red_distane, vehVel])  # 记录每一辆车的[位置和速度]

                if counter > 0 and counter < 19:  # 生成用于机器学习的样本,车辆不超过20
                    avg_speed_lane = 60/3.6
                    max_speed_lane = 60/3.6

                    redTime = max(timeList) - t
                    arrivalTimeDivRedTime = vehicle_Red_distane / \
                        max_speed_lane/(redTime+0.001)

                    # subject为主车样本,
                    # 注意这次我把车道名加入特征中，看一下效果

                    subject = [vehID, max(timeList) - t,  # 主车名，红灯剩余时间
                               vehicle_Red_distane,
                               vehVel,
                               avg_speed_lane,
                               vehicle_Red_distane/(vehVel+0.01),
                               vehicle_Red_distane/avg_speed_lane,
                               vehLaneID, arrivalTimeDivRedTime]

                    # samplesTmp1为当前时刻主车前面的车（最大20车）车辆的状态
                    samplesTmp1 = deepcopy(recordPerVeh)

                    # 主车前面的车（最大20车）车辆的状态
                    samplesTmp1.extend([0, 0]*(19-counter))

                    # samplesTmp2为当前时刻当前样本：主车+主车前面的车（最大20车）+speedFlag
                    samplesTmp2 = deepcopy(subject)  # 当前样本：主车
                    samplesTmp2.extend(samplesTmp1)  # 当前样本：主车+主车前面的车（最大20车）
                    samplesTmp2.extend([speedFlagDict[vehID]])

                    samplesAll.append(samplesTmp2)  # 收集所有的样本

                counter = counter+1

    return samplesAll

###################################################################################################
# 根据交通灯边红色静止车的特征，获得符合特征的红灯静止车


def extractRedVehs(vehInOneEdge):

    redVehs = pd.DataFrame(columns=vehInOneEdge.columns)  # 建立空的二维数组，并且列与数据库一致。

    maxLanePos = max(vehInOneEdge.vehicle_pos)  # 车道的长度

    # 提取红灯车辆以及时刻
    vehInOneEdge = vehInOneEdge.sort_values(
        by='timestep_time', ascending=True)  # 提取持续的时间段
    timeList = vehInOneEdge.timestep_time.unique()

    lowSpeedFlag = 0
    for t in timeList:  # 枚举每个时间，进行分析，获得红灯车辆

        # 当前时刻，当前车道上的所有车
        vehsAtTime = vehInOneEdge[vehInOneEdge.timestep_time == float(t)]

        for index, veh in vehsAtTime.iterrows():  # 每一辆车
            # print(index,veh)
            vehX = veh.vehicle_x
            vehY = veh.vehicle_y
            vehVel = veh.vehicle_speed
            vehTime = veh.timestep_time
            vehID = veh.vehicle_id
            vehicle_pos = veh.vehicle_pos
            if (vehVel < 2/3.6) and (maxLanePos-vehicle_pos < 3):  # 红色静止车辨别标准
                lowSpeedFlag = 1
                redVehs.loc[len(redVehs.index)] = veh

    return redVehs

###################################################################################################
# 根据交通灯边红色静止车的特征，获得符合特征的所有其他车的最小速度
# 认为其他车的最小速度是从计时开始到离开当前车道


def assignLabel(minSpeed):
    '''
    if minSpeed >= 35/3.6:
        speedFlag = 4
    if minSpeed <= 35/3.6 and minSpeed > 25/3.6:
        speedFlag = 3
    if minSpeed <= 25/3.6 and minSpeed > 15/3.6:
        speedFlag = 2
    if minSpeed <= 15/3.6 and minSpeed > 5/3.6:
        speedFlag = 1
    if minSpeed <= 5/3.6:
        speedFlag = 0
    '''
    if minSpeed >40/3.6:
        speedFlag = 8
    if minSpeed <= 40/3.6 and minSpeed > 35/3.6:
        speedFlag = 7
    if minSpeed <= 35/3.6 and minSpeed > 30/3.6:
        speedFlag = 6
    if minSpeed <= 30/3.6 and minSpeed > 25/3.6:
        speedFlag = 5
    if minSpeed <= 25/3.6 and minSpeed > 20/3.6:
        speedFlag = 4
    if minSpeed <= 20/3.6 and minSpeed > 15/3.6:
        speedFlag = 3
    if minSpeed <= 15/3.6 and minSpeed > 10/3.6:
        speedFlag = 2
    if minSpeed <= 10/3.6 and minSpeed > 5/3.6:
        speedFlag = 1
    if minSpeed <= 5/3.6:
        speedFlag = 0

    return speedFlag


def analyzingRedVehAtCurLane(redVehs, vehInOneEdge, curLaneID):

    speedFlagDict = dict()
    maxLanePos = max(vehInOneEdge.vehicle_pos)  # 车道的长度

    for iRed, redID in enumerate(redVehs.vehicle_id.unique()):
        print("analyzingRedVehAtCurLane ", iRed, redID)
        redVehFocusTmp = redVehs[redVehs.vehicle_id == redID]  # 红灯状态的车辆ID
        timeList = redVehFocusTmp.timestep_time.values  # 红灯车的持续时间

        locTmp1 = vehInOneEdge.timestep_time >= min(timeList)
        locTmp2 = vehInOneEdge.timestep_time <= max(timeList)
        # 距离红灯100米以内,红灯时间内车道内所有的车
        locTmp3 = (maxLanePos - vehInOneEdge.vehicle_pos) < 100

        # 红灯时间内车道内所有的车,而且必须距离红灯100米以内，排除绿灯时在道路的车,核心数据1
        vehsAtTimeAndDist = vehInOneEdge[locTmp1 & (locTmp2 & locTmp3)]
        vehIDsAtTimeAndDist = vehsAtTimeAndDist.vehicle_id.unique()  # 符合条件的所有车
        # print(vehsAtTimeAndDist.head(5))

        for ii, idTmp in enumerate(vehIDsAtTimeAndDist):

            # 提取符合ID的车，注意采用的是vehInOneLane，不是vehsAtTimeAndDist.重要！！！
            vehTmp = vehInOneEdge[vehInOneEdge.vehicle_id == idTmp]
            # 提取符合时间的车，  locTmp1 = vehInOneEdge.timestep_time >= min(timeList)
            vehTmp = vehTmp[vehTmp.timestep_time >= min(timeList)]
            # 提取符合位置的的车
            # 100米很重要，因为有可能100开外的车才启动,速度很低
            locTmp3 = (maxLanePos - vehTmp.vehicle_pos) < 100
            vehTmp = vehTmp[locTmp3]
            speedFlag = 0
            if vehTmp.empty == True:
                speedFlag = -1
                speedFlagDict[idTmp] = speedFlag
                continue

            else:
                # 距离红灯100米以内,红灯时间内一部车的是所有速度信息
                minSpeed = min(vehTmp.vehicle_speed.values)
                speedFlagDict[idTmp] = assignLabel(minSpeed)

            del vehTmp
            ############################################
            # 再来一次提取速度标记,附加检查，用于检查样本中一些特殊例子，例如车在当前车道和edge突然不见了,跑到其他edge去了
            # 提取符合ID的车，注意采用的是vehInOneEdge,时间规则

            vehTmp2 = vehInOneEdge[vehInOneEdge.vehicle_id == idTmp]
            vehTmp2 = vehTmp2[vehTmp2.timestep_time >= min(timeList)]

            # 位置规则与vehInOneLane不一样
            # 我认为汽车最后时刻的距离交通灯距离大于10(也就是大于1个车长+变道最小安全距离+1秒速度值），然后不见的原因是变道
            # 注意是vehInOneLane的vehTmp,不是vehInOneEdge的vehTmp2
            dist = maxLanePos-vehTmp2.iloc[-1].vehicle_pos
            vel = vehTmp2.iloc[-1].vehicle_speed

            # 对于变道情况，下面的进行了简化，非常重要
            if (dist) > (5+2+vel):  # 我认为汽车最后时刻的距离交通灯距离大于10(也就是大于1个车长+变道最小安全距离+1秒速度值），然后本车道上突然不见的原因是：变道
                # 最大时间的附加时间的简易算法为距离除以速度+速度除以最大刹车速速（经验值3），因为不见的这段时间的车辆状态，难以预测
                edgeAddMaxTime = round(dist/(vel+0.001)+vel/3)
                edgeAddMaxTime = min(edgeAddMaxTime, 10)  # 限制最大时间的附加时间为10
                vehTmp2 = vehTmp2[vehTmp2.timestep_time <=
                                  max(timeList) + edgeAddMaxTime]

                if vehTmp2.empty == True:
                    speedFlag1 = -1
                else:
                    # 距离红灯100米以内,红灯时间内一部车的是所有速度信息
                    minSpeed = min(vehTmp2.vehicle_speed.values)
                    speedFlag1 = assignLabel(minSpeed)

                speedFlagDict[idTmp] = min(speedFlag, speedFlag1)

    return speedFlagDict

###################################################################################################
###################################################################################################
###################################################################################################
# 主程序


print("主程序：提取法国数据库的主程序。")
print("1.包括生成样本。")
print("2.计算每个样本的提取最小速度。")
print("3.保存为csv文件:france_0_allSamples1.csv")
df = pd.read_csv('../trainData/originFranceData1.csv', sep=';')

laneList = df.vehicle_lane.unique()  # 获得每一条道路
numLanes = len(df.vehicle_lane.unique())


########################################################################################
# 枚举每一个车道,获得红灯附近的车，以及车道的长度
for ilane, curLaneID in enumerate(df.vehicle_lane.unique()):  # 枚举每一个车道

    print("\nlaneIndex is %d,nameID is %s" % (ilane, curLaneID))

    if isinstance(curLaneID, str) == False:
        continue
    curLaneID = laneList[ilane]

    redVehs = pd.DataFrame(columns=df.columns)  # 建立空的二维数组，并且列与数据库一致。

    vehInOneLane = df[df.vehicle_lane == curLaneID]  # 获得当前车道上所有车辆
    vehInOneLane = vehInOneLane.sort_values(
        by='timestep_time', ascending=True)  # 提取持续的时间段

    # 提取edge的名字,先查分割符号查#,再查_
    laneStr = curLaneID
    t1 = laneStr.partition("#")  # 暂时不认为#为edge的分割标志
    t1 = laneStr
    t2 = laneStr.partition("_")

    if t1 == laneStr:
        if t2 == laneStr:
            edgeStr = laneStr
        else:
            edgeStr = t2[0]
    else:
        edgeStr = t1[0]

    resault = df['vehicle_lane'].str.contains(edgeStr)
    # print(resault)
    resault.fillna(value=False, inplace=True)
    vehInOneEdge = df[resault]  # 获得当前edge上所有车辆

    vehInOneEdge = vehInOneEdge.sort_values(
        by='timestep_time', ascending=True)  # 提取持续的时间段

    if vehInOneEdge.empty == True:  # 当前车道没有车
        continue

    # 提取交通灯边的静止车，注意进行了修改，以vehInOneEdge为主，而不是vehInOneLane
    redVehs = extractRedVehs(vehInOneEdge)
    if redVehs.empty == True:  # 如果当前车道没有红灯车
        continue

    # 给出每辆车的最小速度
    speedFlagDict = analyzingRedVehAtCurLane(redVehs, vehInOneEdge, curLaneID)

    # 并生成样本
    samplesAll = genSamples(vehInOneEdge, redVehs, speedFlagDict, vehInOneLane)

    # print("len(speedFlagDict):",len(speedFlagDict1))
    print("len(redVehs):", len(redVehs))
    print("len(samplesAll):", len(samplesAll))

    # 当前车道，每个红灯车的所有时刻的样本
    name1 = ["vehID", "redLightTime", "distToRedLight", "speed", "laneAvgSpeed",
             "arriveTime1", "arriveTime2", "vehLaneID", "ArrTimeDivRedTime"]
    name2 = ["vehPos_1", "vehSpeed_1", "vehPos_2", "vehSpeed_2",
             "vehPos_3", "vehSpeed_3", "vehPos_4", "vehSpeed_4"]
    name3 = ["vehPos_5", "vehSpeed_5", "vehPos_6", "vehSpeed_6",
             "vehPos_7", "vehSpeed_7", "vehPos_8", "vehSpeed_8"]
    name4 = ["vehPos_9", "vehSpeed_9", "vehPos_10", "vehSpeed_10",
             "vehPos_11", "vehSpeed_11", "vehPos_12", "vehSpeed_12"]
    name5 = ["vehPos_13", "vehSpeed_13", "vehPos_14", "vehSpeed_14",
             "vehPos_15", "vehSpeed_15", "vehPos_16", "vehSpeed_16"]
    name6 = ["vehPos_17", "vehSpeed_17", "vehPos_18", "vehSpeed_18",
             "vehPos_19", "vehSpeed_19", "vehPos_20", "vehSpeed_20"]

    headers = name1+name2+name3+name4+name5+name6+["speedFlag"]

    if samplesAll != []:
        # print(samplesAll[0])
        samplesTmp = pd.DataFrame(samplesAll, columns=headers)
        # print(samplesTmp.info())
        filename = '../franceRedData/'+str(ilane)+'+'+curLaneID+'.csv'
        samplesTmp.to_csv(filename, float_format='%.3f', index=0)


###################################################################################
# 将所有样本集合成一个CSV文件
path = "../franceRedData/"

filelist = [path + i for i in os.listdir(path)]
dataset = pd.read_csv(filelist[0])

for tmpFile in filelist:
    if tmpFile.endswith(".csv"):
        # print(tmpFile)
        tmpDF = pd.read_csv(tmpFile)
        dataset = pd.concat([dataset, tmpDF], ignore_index=True, axis=0)


filename = "../trainData/"+"france_0_allSamples1.csv"
dataset.to_csv(filename, float_format='%.3f', index=0)

# !zip ./france_0_allSamples1.zip ./trainData/france_0_allSamples1.csv
# Out:
# 主程序：提取法国数据库的主程序。
# 1.包括生成样本。
# 2.计算每个样本的提取最小速度。
# 3.保存为csv文件:france_0_allSamples1.csv
#
# laneIndex is 0,nameID is -1356_0
# analyzingRedVehAtCurLane  0 BusFlowEastWest0.0
# analyzingRedVehAtCurLane  1 BusFlowEastWest0.1
# analyzingRedVehAtCurLane  2 BusFlowEastWest0.2
# analyzingRedVehAtCurLane  3 BusFlowEastWest.0
# analyzingRedVehAtCurLane  4 BusFlowEastWest.1
# analyzingRedVehAtCurLane  5 BusFlowEastWest.2
# analyzingRedVehAtCurLane  6 BusFlowEastWest.3
# analyzingRedVehAtCurLane  7 BusFlowEastWest1.0
# analyzingRedVehAtCurLane  8 BusFlowEastWest1.2
# analyzingRedVehAtCurLane  9 BusFlowEastWest1.3
# analyzingRedVehAtCurLane  10 BusFlowEastWest2.0
# analyzingRedVehAtCurLane  11 BusFlowEastWest2.1
# analyzingRedVehAtCurLane  12 BusFlowEastWest2.3
# analyzingRedVehAtCurLane  13 BusFlowEastWest3.0
# analyzingRedVehAtCurLane  14 BusFlowEastWest3.1
# analyzingRedVehAtCurLane  15 BusFlowEastWest3.2
# analyzingRedVehAtCurLane  16 BusFlowEastWest3.4
# analyzingRedVehAtCurLane  17 BusFlowEastWest3.5
# analyzingRedVehAtCurLane  18 BusFlowEastWest4.0
# analyzingRedVehAtCurLane  19 BusFlowEastWest4.1
# analyzingRedVehAtCurLane  20 BusFlowEastWest4.2
# analyzingRedVehAtCurLane  21 BusFlowEastWest4.3
# analyzingRedVehAtCurLane  22 BusFlowEastWest4.4
# analyzingRedVehAtCurLane  23 BusFlowEastWest5.0
# analyzingRedVehAtCurLane  24 BusFlowEastWest5.1
# analyzingRedVehAtCurLane  25 BusFlowEastWest5.2
# analyzingRedVehAtCurLane  26 BusFlowEastWest5.3
# analyzingRedVehAtCurLane  27 BusFlowEastWest5.4
# analyzingRedVehAtCurLane  28 BusFlowEastWest5.5
# analyzingRedVehAtCurLane  29 BusFlowEastWest6.1
# analyzingRedVehAtCurLane  30 BusFlowEastWest6.2
# genSamples 0 BusFlowEastWest0.0
# genSamples 1 BusFlowEastWest0.1
#  redID: BusFlowEastWest0.1   (max(timeList) - min(timeList))<3
# genSamples 2 BusFlowEastWest0.2
# genSamples 3 BusFlowEastWest.0
# genSamples 4 BusFlowEastWest.1
# genSamples 5 BusFlowEastWest.2
# genSamples 6 BusFlowEastWest.3
#  redID: BusFlowEastWest.3   (max(timeList) - min(timeList))<3
# genSamples 7 BusFlowEastWest1.0
# genSamples 8 BusFlowEastWest1.2
#  redID: BusFlowEastWest1.2   (max(timeList) - min(timeList))<3
# genSamples 9 BusFlowEastWest1.3
# genSamples 10 BusFlowEastWest2.0
#  redID: BusFlowEastWest2.0   (max(timeList) - min(timeList))<3
# genSamples 11 BusFlowEastWest2.1
# genSamples 12 BusFlowEastWest2.3
# genSamples 13 BusFlowEastWest3.0
# genSamples 14 BusFlowEastWest3.1
#  redID: BusFlowEastWest3.1   (max(timeList) - min(timeList))<3
# genSamples 15 BusFlowEastWest3.2
# genSamples 16 BusFlowEastWest3.4
#  redID: BusFlowEastWest3.4   (max(timeList) - min(timeList))<3
# genSamples 17 BusFlowEastWest3.5
# genSamples 18 BusFlowEastWest4.0
#  redID: BusFlowEastWest4.0   (max(timeList) - min(timeList))<3
# genSamples 19 BusFlowEastWest4.1
# genSamples 20 BusFlowEastWest4.2
# genSamples 21 BusFlowEastWest4.3
#  redID: BusFlowEastWest4.3   (max(timeList) - min(timeList))<3
# genSamples 22 BusFlowEastWest4.4
# genSamples 23 BusFlowEastWest5.0
#  redID: BusFlowEastWest5.0   (max(timeList) - min(timeList))<3
# genSamples 24 BusFlowEastWest5.1
# genSamples 25 BusFlowEastWest5.2
#  redID: BusFlowEastWest5.2   (max(timeList) - min(timeList))<3
# genSamples 26 BusFlowEastWest5.3
# genSamples 27 BusFlowEastWest5.4
#  redID: BusFlowEastWest5.4   (max(timeList) - min(timeList))<3
# genSamples 28 BusFlowEastWest5.5
# genSamples 29 BusFlowEastWest6.1
# genSamples 30 BusFlowEastWest6.2
# len(redVehs): 196
# len(samplesAll): 0
#
# laneIndex is 1,nameID is 28925528_0
# analyzingRedVehAtCurLane  0 BusFlowNorthSouth0.0
# analyzingRedVehAtCurLane  1 VehicleFlowNorthToWest.0
# analyzingRedVehAtCurLane  2 VehicleFlowNorthToSouth.1
# analyzingRedVehAtCurLane  3 VehicleFlowNorthToWest.2
# analyzingRedVehAtCurLane  4 VehicleFlowNorthToWest.3
# analyzingRedVehAtCurLane  5 VehicleFlowNorthToSouth.2
# analyzingRedVehAtCurLane  6 VehicleFlowNorthToSouth.3
# analyzingRedVehAtCurLane  7 VehicleFlowNorthToWest.5
# analyzingRedVehAtCurLane  8 VehicleFlowNorthToWest.6
# analyzingRedVehAtCurLane  9 VehicleFlowNorthToSouth.4
# analyzingRedVehAtCurLane  10 VehicleFlowNorthToWest.8
# analyzingRedVehAtCurLane  11 VehicleFlowNorthToSouth.5
# analyzingRedVehAtCurLane  12 VehicleFlowNorthToWest.9
# analyzingRedVehAtCurLane  13 VehicleFlowNorthToWest.11
# analyzingRedVehAtCurLane  14 VehicleFlowNorthToEast.7
# analyzingRedVehAtCurLane  15 VehicleFlowNorthToWest.12
# analyzingRedVehAtCurLane  16 VehicleFlowNorthToEast.8
# analyzingRedVehAtCurLane  17 VehicleFlowNorthToWest.14
# analyzingRedVehAtCurLane  18 VehicleFlowNorthToWest.15
# analyzingRedVehAtCurLane  19 VehicleFlowNorthToEast.9
# analyzingRedVehAtCurLane  20 VehicleFlowNorthToSouth.10
# analyzingRedVehAtCurLane  21 VehicleFlowNorthToWest.17
# analyzingRedVehAtCurLane  22 BusFlowNorthSouth0.1
# analyzingRedVehAtCurLane  23 VehicleFlowNorthToWest.18
# analyzingRedVehAtCurLane  24 VehicleFlowNorthToWest.19
# analyzingRedVehAtCurLane  25 VehicleFlowNorthToSouth.12
# analyzingRedVehAtCurLane  26 VehicleFlowNorthToSouth.13
# analyzingRedVehAtCurLane  27 VehicleFlowNorthToWest.21
# analyzingRedVehAtCurLane  28 VehicleFlowNorthToWest.22
# analyzingRedVehAtCurLane  29 VehicleFlowNorthToSouth.14
# analyzingRedVehAtCurLane  30 VehicleFlowNorthToEast.14
# analyzingRedVehAtCurLane  31 VehicleFlowNorthToWest.24
# analyzingRedVehAtCurLane  32 VehicleFlowNorthToWest.25
# analyzingRedVehAtCurLane  33 VehicleFlowNorthToEast.15
# analyzingRedVehAtCurLane  34 VehicleFlowNorthToEast.16
# analyzingRedVehAtCurLane  35 VehicleFlowNorthToWest.27
# analyzingRedVehAtCurLane  36 VehicleFlowNorthToWest.28
# analyzingRedVehAtCurLane  37 VehicleFlowNorthToEast.17
# analyzingRedVehAtCurLane  38 VehicleFlowNorthToWest.30
# analyzingRedVehAtCurLane  39 VehicleFlowNorthToSouth.19
# analyzingRedVehAtCurLane  40 VehicleFlowNorthToWest.31
# analyzingRedVehAtCurLane  41 VehicleFlowNorthToSouth.20
# analyzingRedVehAtCurLane  42 VehicleFlowNorthToWest.33
# analyzingRedVehAtCurLane  43 VehicleFlowNorthToEast.20
# analyzingRedVehAtCurLane  44 VehicleFlowNorthToWest.34
# analyzingRedVehAtCurLane  45 VehicleFlowNorthToEast.21
# analyzingRedVehAtCurLane  46 VehicleFlowNorthToEast.22
# analyzingRedVehAtCurLane  47 VehicleFlowNorthToWest.37
# analyzingRedVehAtCurLane  48 VehicleFlowNorthToWest.38
# analyzingRedVehAtCurLane  49 VehicleFlowNorthToEast.23
# analyzingRedVehAtCurLane  50 VehicleFlowNorthToEast1.0
# analyzingRedVehAtCurLane  51 VehicleFlowNorthToWest1.0
# analyzingRedVehAtCurLane  52 VehicleFlowNorthToWest.41
# analyzingRedVehAtCurLane  53 VehicleFlowNorthToWest1.2
# analyzingRedVehAtCurLane  54 VehicleFlowNorthToWest1.4
# analyzingRedVehAtCurLane  55 VehicleFlowNorthToEast1.2
# analyzingRedVehAtCurLane  56 VehicleFlowNorthToWest1.5
# analyzingRedVehAtCurLane  57 VehicleFlowNorthToWest1.7
# analyzingRedVehAtCurLane  58 VehicleFlowNorthToWest1.8
# analyzingRedVehAtCurLane  59 VehicleFlowNorthToSouth1.3
# analyzingRedVehAtCurLane  60 VehicleFlowNorthToEast1.4
# analyzingRedVehAtCurLane  61 VehicleFlowNorthToWest1.10
# analyzingRedVehAtCurLane  62 VehicleFlowNorthToWest1.12
# analyzingRedVehAtCurLane  63 VehicleFlowNorthToWest1.13
# analyzingRedVehAtCurLane  64 VehicleFlowNorthToEast1.6
# analyzingRedVehAtCurLane  65 VehicleFlowNorthToWest1.15
# analyzingRedVehAtCurLane  66 VehicleFlowNorthToWest1.16
# analyzingRedVehAtCurLane  67 VehicleFlowNorthToSouth1.6
# analyzingRedVehAtCurLane  68 VehicleFlowNorthToWest1.18
# analyzingRedVehAtCurLane  69 VehicleFlowNorthToSouth1.7
# analyzingRedVehAtCurLane  70 VehicleFlowNorthToWest1.20
# analyzingRedVehAtCurLane  71 VehicleFlowNorthToWest1.21
# analyzingRedVehAtCurLane  72 BusFlowNorthSouth.1
# analyzingRedVehAtCurLane  73 VehicleFlowNorthToWest1.23
# analyzingRedVehAtCurLane  74 VehicleFlowNorthToEast1.10
# analyzingRedVehAtCurLane  75 VehicleFlowNorthToWest1.25
# analyzingRedVehAtCurLane  76 VehicleFlowNorthToWest1.26
# analyzingRedVehAtCurLane  77 VehicleFlowNorthToSouth1.10
# analyzingRedVehAtCurLane  78 VehicleFlowNorthToWest1.28
# analyzingRedVehAtCurLane  79 VehicleFlowNorthToWest1.29
# analyzingRedVehAtCurLane  80 VehicleFlowNorthToEast1.12
# analyzingRedVehAtCurLane  81 VehicleFlowNorthToWest1.31
# analyzingRedVehAtCurLane  82 VehicleFlowNorthToWest1.33
# analyzingRedVehAtCurLane  83 VehicleFlowNorthToSouth1.12
# analyzingRedVehAtCurLane  84 VehicleFlowNorthToWest1.34
# analyzingRedVehAtCurLane  85 VehicleFlowNorthToEast1.14
# analyzingRedVehAtCurLane  86 VehicleFlowNorthToSouth1.13
# analyzingRedVehAtCurLane  87 VehicleFlowNorthToWest1.36
# analyzingRedVehAtCurLane  88 VehicleFlowNorthToEast1.15
# analyzingRedVehAtCurLane  89 VehicleFlowNorthToWest1.38
# analyzingRedVehAtCurLane  90 VehicleFlowNorthToSouth1.14
# analyzingRedVehAtCurLane  91 VehicleFlowNorthToWest1.39
# analyzingRedVehAtCurLane  92 VehicleFlowNorthToWest1.41
# analyzingRedVehAtCurLane  93 VehicleFlowNorthToWest1.42
# analyzingRedVehAtCurLane  94 VehicleFlowNorthToEast1.17
# analyzingRedVehAtCurLane  95 VehicleFlowNorthToWest1.44
# analyzingRedVehAtCurLane  96 VehicleFlowNorthToSouth1.16
# analyzingRedVehAtCurLane  97 VehicleFlowNorthToWest1.46
# analyzingRedVehAtCurLane  98 BusFlowNorthSouth1.0
# analyzingRedVehAtCurLane  99 VehicleFlowNorthToWest2.1
# analyzingRedVehAtCurLane  100 VehicleFlowNorthToEast2.1
# analyzingRedVehAtCurLane  101 VehicleFlowNorthToWest2.3
# analyzingRedVehAtCurLane  102 VehicleFlowNorthToWest2.5
# analyzingRedVehAtCurLane  103 VehicleFlowNorthToEast2.2
# analyzingRedVehAtCurLane  104 VehicleFlowNorthToSouth2.2
# analyzingRedVehAtCurLane  105 VehicleFlowNorthToWest2.7
# analyzingRedVehAtCurLane  106 VehicleFlowNorthToWest2.9
# analyzingRedVehAtCurLane  107 VehicleFlowNorthToWest2.11
# analyzingRedVehAtCurLane  108 VehicleFlowNorthToEast2.5
# analyzingRedVehAtCurLane  109 VehicleFlowNorthToWest2.13
# analyzingRedVehAtCurLane  110 VehicleFlowNorthToWest2.15
# analyzingRedVehAtCurLane  111 VehicleFlowNorthToEast2.6
# analyzingRedVehAtCurLane  112 VehicleFlowNorthToSouth2.5
# analyzingRedVehAtCurLane  113 VehicleFlowNorthToWest2.17
# analyzingRedVehAtCurLane  114 VehicleFlowNorthToWest2.19
# analyzingRedVehAtCurLane  115 VehicleFlowNorthToEast2.8
# analyzingRedVehAtCurLane  116 VehicleFlowNorthToWest2.21
# analyzingRedVehAtCurLane  117 VehicleFlowNorthToEast2.9
# analyzingRedVehAtCurLane  118 VehicleFlowNorthToWest2.23
# analyzingRedVehAtCurLane  119 VehicleFlowNorthToWest2.25
# analyzingRedVehAtCurLane  120 BusFlowNorthSouth1.1
# analyzingRedVehAtCurLane  121 VehicleFlowNorthToWest2.27
# analyzingRedVehAtCurLane  122 VehicleFlowNorthToEast2.11
# analyzingRedVehAtCurLane  123 VehicleFlowNorthToWest2.29
# analyzingRedVehAtCurLane  124 VehicleFlowNorthToWest2.30
# analyzingRedVehAtCurLane  125 VehicleFlowNorthToEast2.12
# analyzingRedVehAtCurLane  126 VehicleFlowNorthToWest2.32
# analyzingRedVehAtCurLane  127 VehicleFlowNorthToSouth2.10
# analyzingRedVehAtCurLane  128 VehicleFlowNorthToWest2.34
# analyzingRedVehAtCurLane  129 VehicleFlowNorthToWest2.35
# analyzingRedVehAtCurLane  130 VehicleFlowNorthToWest2.36
# analyzingRedVehAtCurLane  131 VehicleFlowNorthToSouth2.11
# analyzingRedVehAtCurLane  132 VehicleFlowNorthToWest2.38
# analyzingRedVehAtCurLane  133 VehicleFlowNorthToEast2.15
# analyzingRedVehAtCurLane  134 VehicleFlowNorthToWest2.40
# analyzingRedVehAtCurLane  135 VehicleFlowNorthToEast2.16
# analyzingRedVehAtCurLane  136 VehicleFlowNorthToWest2.42
# analyzingRedVehAtCurLane  137 VehicleFlowNorthToSouth2.13
# analyzingRedVehAtCurLane  138 VehicleFlowNorthToWest2.44
# analyzingRedVehAtCurLane  139 VehicleFlowNorthToWest2.45
# analyzingRedVehAtCurLane  140 VehicleFlowNorthToEast2.18
# analyzingRedVehAtCurLane  141 VehicleFlowNorthToWest2.46
# analyzingRedVehAtCurLane  142 VehicleFlowNorthToWest2.48
# analyzingRedVehAtCurLane  143 VehicleFlowNorthToEast2.19
# analyzingRedVehAtCurLane  144 VehicleFlowNorthToWest2.50
# analyzingRedVehAtCurLane  145 VehicleFlowNorthToEast2.20
# analyzingRedVehAtCurLane  146 VehicleFlowNorthToWest2.52
# analyzingRedVehAtCurLane  147 VehicleFlowNorthToSouth2.16
# analyzingRedVehAtCurLane  148 VehicleFlowNorthToWest2.54
# analyzingRedVehAtCurLane  149 BusFlowNorthSouth2.0
# analyzingRedVehAtCurLane  150 VehicleFlowNorthToWest3.1
# analyzingRedVehAtCurLane  151 VehicleFlowNorthToWest3.2
# analyzingRedVehAtCurLane  152 VehicleFlowNorthToSouth3.1
# analyzingRedVehAtCurLane  153 VehicleFlowNorthToWest3.4
# analyzingRedVehAtCurLane  154 VehicleFlowNorthToSouth3.2
# analyzingRedVehAtCurLane  155 VehicleFlowNorthToWest3.5
# analyzingRedVehAtCurLane  156 VehicleFlowNorthToWest3.7
# analyzingRedVehAtCurLane  157 VehicleFlowNorthToWest3.8
# analyzingRedVehAtCurLane  158 VehicleFlowNorthToSouth3.4
# analyzingRedVehAtCurLane  159 VehicleFlowNorthToWest3.10
# analyzingRedVehAtCurLane  160 VehicleFlowNorthToEast3.7
# analyzingRedVehAtCurLane  161 VehicleFlowNorthToWest3.11
# analyzingRedVehAtCurLane  162 VehicleFlowNorthToEast3.8
# analyzingRedVehAtCurLane  163 VehicleFlowNorthToSouth3.6
# analyzingRedVehAtCurLane  164 VehicleFlowNorthToWest3.13
# analyzingRedVehAtCurLane  165 VehicleFlowNorthToWest3.14
# analyzingRedVehAtCurLane  166 VehicleFlowNorthToSouth3.7
# analyzingRedVehAtCurLane  167 VehicleFlowNorthToWest3.16
# analyzingRedVehAtCurLane  168 VehicleFlowNorthToEast3.11
# analyzingRedVehAtCurLane  169 VehicleFlowNorthToWest3.17
# analyzingRedVehAtCurLane  170 VehicleFlowNorthToEast3.12
# analyzingRedVehAtCurLane  171 VehicleFlowNorthToSouth3.9
# analyzingRedVehAtCurLane  172 VehicleFlowNorthToWest3.19
# analyzingRedVehAtCurLane  173 VehicleFlowNorthToWest3.20
# analyzingRedVehAtCurLane  174 VehicleFlowNorthToEast3.14
# analyzingRedVehAtCurLane  175 VehicleFlowNorthToWest3.22
# analyzingRedVehAtCurLane  176 VehicleFlowNorthToWest3.23
# analyzingRedVehAtCurLane  177 VehicleFlowNorthToEast3.16
# analyzingRedVehAtCurLane  178 VehicleFlowNorthToSouth3.12
# analyzingRedVehAtCurLane  179 VehicleFlowNorthToWest3.25
# analyzingRedVehAtCurLane  180 VehicleFlowNorthToWest3.26
# analyzingRedVehAtCurLane  181 VehicleFlowNorthToEast3.18
# analyzingRedVehAtCurLane  182 VehicleFlowNorthToEast3.19
# analyzingRedVehAtCurLane  183 VehicleFlowNorthToWest3.28
# analyzingRedVehAtCurLane  184 VehicleFlowNorthToSouth3.14
# analyzingRedVehAtCurLane  185 VehicleFlowNorthToWest3.29
# analyzingRedVehAtCurLane  186 VehicleFlowNorthToEast3.21
# analyzingRedVehAtCurLane  187 VehicleFlowNorthToWest3.31
# analyzingRedVehAtCurLane  188 VehicleFlowNorthToWest3.32
# analyzingRedVehAtCurLane  189 VehicleFlowNorthToEast3.22
# analyzingRedVehAtCurLane  190 VehicleFlowNorthToEast3.23
# analyzingRedVehAtCurLane  191 VehicleFlowNorthToWest3.34
# analyzingRedVehAtCurLane  192 VehicleFlowNorthToSouth3.17
# analyzingRedVehAtCurLane  193 VehicleFlowNorthToWest3.35
# analyzingRedVehAtCurLane  194 VehicleFlowNorthToEast3.25
# analyzingRedVehAtCurLane  195 VehicleFlowNorthToWest3.37
# analyzingRedVehAtCurLane  196 VehicleFlowNorthToWest3.38
# analyzingRedVehAtCurLane  197 VehicleFlowNorthToEast3.26
# analyzingRedVehAtCurLane  198 VehicleFlowNorthToEast3.27
# analyzingRedVehAtCurLane  199 VehicleFlowNorthToWest3.40
# analyzingRedVehAtCurLane  200 VehicleFlowNorthToWest4.0
# analyzingRedVehAtCurLane  201 VehicleFlowNorthToWest4.1
# analyzingRedVehAtCurLane  202 VehicleFlowNorthToWest4.2
# analyzingRedVehAtCurLane  203 VehicleFlowNorthToEast4.1
# analyzingRedVehAtCurLane  204 VehicleFlowNorthToWest4.4
# analyzingRedVehAtCurLane  205 VehicleFlowNorthToEast4.2
# analyzingRedVehAtCurLane  206 VehicleFlowNorthToWest4.5
# analyzingRedVehAtCurLane  207 VehicleFlowNorthToWest4.7
# analyzingRedVehAtCurLane  208 VehicleFlowNorthToWest4.8
# analyzingRedVehAtCurLane  209 VehicleFlowNorthToWest4.9
# analyzingRedVehAtCurLane  210 VehicleFlowNorthToEast4.4
# analyzingRedVehAtCurLane  211 VehicleFlowNorthToWest4.11
# analyzingRedVehAtCurLane  212 VehicleFlowNorthToSouth4.5
# analyzingRedVehAtCurLane  213 VehicleFlowNorthToWest4.12
# analyzingRedVehAtCurLane  214 VehicleFlowNorthToWest4.14
# analyzingRedVehAtCurLane  215 VehicleFlowNorthToEast4.6
# analyzingRedVehAtCurLane  216 VehicleFlowNorthToWest4.15
# analyzingRedVehAtCurLane  217 VehicleFlowNorthToEast4.7
# analyzingRedVehAtCurLane  218 VehicleFlowNorthToWest4.17
# analyzingRedVehAtCurLane  219 BusFlowNorthSouth3.1
# analyzingRedVehAtCurLane  220 VehicleFlowNorthToWest4.18
# analyzingRedVehAtCurLane  221 VehicleFlowNorthToWest4.20
# analyzingRedVehAtCurLane  222 VehicleFlowNorthToWest4.21
# analyzingRedVehAtCurLane  223 VehicleFlowNorthToSouth4.9
# analyzingRedVehAtCurLane  224 VehicleFlowNorthToWest4.23
# analyzingRedVehAtCurLane  225 VehicleFlowNorthToSouth4.10
# analyzingRedVehAtCurLane  226 VehicleFlowNorthToWest4.24
# analyzingRedVehAtCurLane  227 VehicleFlowNorthToEast4.11
# analyzingRedVehAtCurLane  228 VehicleFlowNorthToWest4.27
# analyzingRedVehAtCurLane  229 VehicleFlowNorthToWest4.28
# analyzingRedVehAtCurLane  230 VehicleFlowNorthToEast4.12
# analyzingRedVehAtCurLane  231 VehicleFlowNorthToWest4.30
# analyzingRedVehAtCurLane  232 VehicleFlowNorthToWest4.31
# analyzingRedVehAtCurLane  233 VehicleFlowNorthToEast4.14
# analyzingRedVehAtCurLane  234 VehicleFlowNorthToWest4.33
# analyzingRedVehAtCurLane  235 VehicleFlowNorthToWest4.34
# analyzingRedVehAtCurLane  236 VehicleFlowNorthToEast4.15
# analyzingRedVehAtCurLane  237 VehicleFlowNorthToWest4.36
# analyzingRedVehAtCurLane  238 VehicleFlowNorthToWest4.37
# analyzingRedVehAtCurLane  239 VehicleFlowNorthToEast4.16
# analyzingRedVehAtCurLane  240 VehicleFlowNorthToWest4.39
# analyzingRedVehAtCurLane  241 VehicleFlowNorthToEast6.0
# analyzingRedVehAtCurLane  242 VehicleFlowNorthToWest6.0
# analyzingRedVehAtCurLane  243 VehicleFlowNorthToWest6.1
# analyzingRedVehAtCurLane  244 VehicleFlowNorthToEast6.1
# analyzingRedVehAtCurLane  245 VehicleFlowNorthToSouth6.1
# analyzingRedVehAtCurLane  246 VehicleFlowNorthToWest6.3
# analyzingRedVehAtCurLane  247 VehicleFlowNorthToWest6.4
# analyzingRedVehAtCurLane  248 VehicleFlowNorthToWest6.5
# analyzingRedVehAtCurLane  249 VehicleFlowNorthToEast6.3
# analyzingRedVehAtCurLane  250 VehicleFlowNorthToEast6.4
# analyzingRedVehAtCurLane  251 VehicleFlowNorthToWest6.8
# analyzingRedVehAtCurLane  252 VehicleFlowNorthToWest6.9
# analyzingRedVehAtCurLane  253 VehicleFlowNorthToSouth6.4
# analyzingRedVehAtCurLane  254 VehicleFlowNorthToWest6.10
# analyzingRedVehAtCurLane  255 VehicleFlowNorthToEast6.6
# analyzingRedVehAtCurLane  256 VehicleFlowNorthToSouth6.5
# analyzingRedVehAtCurLane  257 VehicleFlowNorthToWest6.13
# analyzingRedVehAtCurLane  258 VehicleFlowNorthToSouth6.6
# analyzingRedVehAtCurLane  259 VehicleFlowNorthToWest6.14
# analyzingRedVehAtCurLane  260 VehicleFlowNorthToWest6.15
# analyzingRedVehAtCurLane  261 VehicleFlowNorthToEast6.9
# analyzingRedVehAtCurLane  262 VehicleFlowNorthToEast6.10
# analyzingRedVehAtCurLane  263 VehicleFlowNorthToWest6.17
# analyzingRedVehAtCurLane  264 VehicleFlowNorthToWest6.18
# analyzingRedVehAtCurLane  265 VehicleFlowNorthToWest6.19
# analyzingRedVehAtCurLane  266 VehicleFlowNorthToEast6.12
# analyzingRedVehAtCurLane  267 VehicleFlowNorthToEast6.13
# analyzingRedVehAtCurLane  268 VehicleFlowNorthToWest6.22
# analyzingRedVehAtCurLane  269 VehicleFlowNorthToWest6.23
# analyzingRedVehAtCurLane  270 VehicleFlowNorthToSouth6.10
# analyzingRedVehAtCurLane  271 BusFlowNorthSouth4.2
# analyzingRedVehAtCurLane  272 VehicleFlowNorthToWest6.24
# analyzingRedVehAtCurLane  273 VehicleFlowNorthToEast6.15
# analyzingRedVehAtCurLane  274 VehicleFlowNorthToEast6.16
# analyzingRedVehAtCurLane  275 VehicleFlowNorthToWest6.27
# analyzingRedVehAtCurLane  276 VehicleFlowNorthToSouth6.12
# analyzingRedVehAtCurLane  277 VehicleFlowNorthToWest6.28
# analyzingRedVehAtCurLane  278 VehicleFlowNorthToWest6.29
# analyzingRedVehAtCurLane  279 VehicleFlowNorthToEast6.18
# analyzingRedVehAtCurLane  280 VehicleFlowNorthToWest6.31
# analyzingRedVehAtCurLane  281 VehicleFlowNorthToEast6.19
# analyzingRedVehAtCurLane  282 VehicleFlowNorthToWest6.32
# analyzingRedVehAtCurLane  283 VehicleFlowNorthToWest6.33
# analyzingRedVehAtCurLane  284 VehicleFlowNorthToSouth6.15
# analyzingRedVehAtCurLane  285 VehicleFlowNorthToWest6.36
# analyzingRedVehAtCurLane  286 VehicleFlowNorthToEast5.0
# analyzingRedVehAtCurLane  287 VehicleFlowNorthToWest5.0
# analyzingRedVehAtCurLane  288 VehicleFlowNorthToWest5.1
# analyzingRedVehAtCurLane  289 VehicleFlowNorthToEast5.1
# analyzingRedVehAtCurLane  290 VehicleFlowNorthToSouth5.1
# analyzingRedVehAtCurLane  291 VehicleFlowNorthToWest5.4
# analyzingRedVehAtCurLane  292 VehicleFlowNorthToEast5.3
# analyzingRedVehAtCurLane  293 VehicleFlowNorthToWest5.5
# analyzingRedVehAtCurLane  294 VehicleFlowNorthToWest5.6
# analyzingRedVehAtCurLane  295 VehicleFlowNorthToSouth5.4
# analyzingRedVehAtCurLane  296 VehicleFlowNorthToWest5.9
# analyzingRedVehAtCurLane  297 VehicleFlowNorthToEast5.7
# analyzingRedVehAtCurLane  298 VehicleFlowNorthToWest5.10
# analyzingRedVehAtCurLane  299 VehicleFlowNorthToWest5.11
# analyzingRedVehAtCurLane  300 VehicleFlowNorthToEast5.8
# analyzingRedVehAtCurLane  301 VehicleFlowNorthToWest5.12
# analyzingRedVehAtCurLane  302 VehicleFlowNorthToEast5.9
# analyzingRedVehAtCurLane  303 VehicleFlowNorthToSouth5.6
# analyzingRedVehAtCurLane  304 VehicleFlowNorthToWest5.14
# analyzingRedVehAtCurLane  305 VehicleFlowNorthToWest5.15
# analyzingRedVehAtCurLane  306 VehicleFlowNorthToEast5.11
# analyzingRedVehAtCurLane  307 VehicleFlowNorthToWest5.16
# analyzingRedVehAtCurLane  308 VehicleFlowNorthToWest5.19
# analyzingRedVehAtCurLane  309 VehicleFlowNorthToWest5.20
# analyzingRedVehAtCurLane  310 VehicleFlowNorthToSouth5.9
# analyzingRedVehAtCurLane  311 VehicleFlowNorthToEast5.15
# analyzingRedVehAtCurLane  312 VehicleFlowNorthToWest5.21
# analyzingRedVehAtCurLane  313 VehicleFlowNorthToWest5.22
# analyzingRedVehAtCurLane  314 VehicleFlowNorthToEast5.16
# analyzingRedVehAtCurLane  315 VehicleFlowNorthToEast5.17
# analyzingRedVehAtCurLane  316 VehicleFlowNorthToSouth5.11
# analyzingRedVehAtCurLane  317 VehicleFlowNorthToWest5.25
# analyzingRedVehAtCurLane  318 VehicleFlowNorthToWest5.26
# analyzingRedVehAtCurLane  319 VehicleFlowNorthToEast5.19
# analyzingRedVehAtCurLane  320 VehicleFlowNorthToSouth5.12
# analyzingRedVehAtCurLane  321 VehicleFlowNorthToWest5.27
# analyzingRedVehAtCurLane  322 VehicleFlowNorthToWest5.30
# analyzingRedVehAtCurLane  323 VehicleFlowNorthToWest5.31
# analyzingRedVehAtCurLane  324 VehicleFlowNorthToWest5.32
# analyzingRedVehAtCurLane  325 VehicleFlowNorthToEast5.24
# analyzingRedVehAtCurLane  326 VehicleFlowNorthToEast5.25
# analyzingRedVehAtCurLane  327 VehicleFlowNorthToWest5.35
# analyzingRedVehAtCurLane  328 VehicleFlowNorthToEast7.0
# analyzingRedVehAtCurLane  329 VehicleFlowNorthToWest7.0
# analyzingRedVehAtCurLane  330 VehicleFlowNorthToWest7.1
# analyzingRedVehAtCurLane  331 VehicleFlowNorthToWest7.2
# analyzingRedVehAtCurLane  332 VehicleFlowNorthToSouth7.1
# analyzingRedVehAtCurLane  333 VehicleFlowNorthToWest7.3
# analyzingRedVehAtCurLane  334 VehicleFlowNorthToEast7.2
# analyzingRedVehAtCurLane  335 VehicleFlowNorthToEast7.3
# analyzingRedVehAtCurLane  336 VehicleFlowNorthToWest7.7
# analyzingRedVehAtCurLane  337 VehicleFlowNorthToSouth7.3
# analyzingRedVehAtCurLane  338 VehicleFlowNorthToWest7.8
# analyzingRedVehAtCurLane  339 VehicleFlowNorthToWest7.9
# analyzingRedVehAtCurLane  340 VehicleFlowNorthToEast7.6
# analyzingRedVehAtCurLane  341 VehicleFlowNorthToSouth7.4
# analyzingRedVehAtCurLane  342 VehicleFlowNorthToWest7.10
# analyzingRedVehAtCurLane  343 VehicleFlowNorthToEast7.7
# analyzingRedVehAtCurLane  344 VehicleFlowNorthToWest7.11
# analyzingRedVehAtCurLane  345 VehicleFlowNorthToWest7.12
# analyzingRedVehAtCurLane  346 VehicleFlowNorthToEast7.8
# analyzingRedVehAtCurLane  347 VehicleFlowNorthToWest7.13
# analyzingRedVehAtCurLane  348 VehicleFlowNorthToWest7.14
# analyzingRedVehAtCurLane  349 VehicleFlowNorthToEast7.10
# analyzingRedVehAtCurLane  350 VehicleFlowNorthToEast7.11
# analyzingRedVehAtCurLane  351 VehicleFlowNorthToWest7.19
# analyzingRedVehAtCurLane  352 VehicleFlowNorthToSouth7.8
# analyzingRedVehAtCurLane  353 VehicleFlowNorthToWest7.20
# analyzingRedVehAtCurLane  354 VehicleFlowNorthToWest7.21
# analyzingRedVehAtCurLane  355 VehicleFlowNorthToWest7.22
# analyzingRedVehAtCurLane  356 VehicleFlowNorthToSouth7.9
# analyzingRedVehAtCurLane  357 VehicleFlowNorthToEast7.15
# analyzingRedVehAtCurLane  358 VehicleFlowNorthToWest7.23
# analyzingRedVehAtCurLane  359 VehicleFlowNorthToWest7.24
# analyzingRedVehAtCurLane  360 VehicleFlowNorthToEast7.16
# analyzingRedVehAtCurLane  361 VehicleFlowNorthToWest7.25
# analyzingRedVehAtCurLane  362 VehicleFlowNorthToEast7.18
# analyzingRedVehAtCurLane  363 VehicleFlowNorthToEast7.19
# analyzingRedVehAtCurLane  364 VehicleFlowNorthToSouth7.12
# analyzingRedVehAtCurLane  365 VehicleFlowNorthToWest7.30
# analyzingRedVehAtCurLane  366 VehicleFlowNorthToWest7.31
# genSamples 0 BusFlowNorthSouth0.0
#  redID: BusFlowNorthSouth0.0   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 1 VehicleFlowNorthToWest.0
#  redID: VehicleFlowNorthToWest.0   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 2 VehicleFlowNorthToSouth.1
#  redID: VehicleFlowNorthToSouth.1   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 3 VehicleFlowNorthToWest.2
#  redID: VehicleFlowNorthToWest.2   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 4 VehicleFlowNorthToWest.3
#  redID: VehicleFlowNorthToWest.3   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 5 VehicleFlowNorthToSouth.2
#  redID: VehicleFlowNorthToSouth.2   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 6 VehicleFlowNorthToSouth.3
#  redID: VehicleFlowNorthToSouth.3   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 7 VehicleFlowNorthToWest.5
#  redID: VehicleFlowNorthToWest.5   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 8 VehicleFlowNorthToWest.6
#  redID: VehicleFlowNorthToWest.6   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 9 VehicleFlowNorthToSouth.4
#  redID: VehicleFlowNorthToSouth.4   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 10 VehicleFlowNorthToWest.8
#  redID: VehicleFlowNorthToWest.8   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 11 VehicleFlowNorthToSouth.5
#  redID: VehicleFlowNorthToSouth.5   (max(timeList) - min(timeList))<3
# genSamples 12 VehicleFlowNorthToWest.9
#  redID: VehicleFlowNorthToWest.9   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 13 VehicleFlowNorthToWest.11
#  redID: VehicleFlowNorthToWest.11   (max(timeList) - min(timeList))<3
# genSamples 14 VehicleFlowNorthToEast.7
#  redID: VehicleFlowNorthToEast.7   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 15 VehicleFlowNorthToWest.12
#  redID: VehicleFlowNorthToWest.12   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 16 VehicleFlowNorthToEast.8
#  redID: VehicleFlowNorthToEast.8   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 17 VehicleFlowNorthToWest.14
#  redID: VehicleFlowNorthToWest.14   (max(timeList) - min(timeList))<3
# genSamples 18 VehicleFlowNorthToWest.15
#  redID: VehicleFlowNorthToWest.15   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 19 VehicleFlowNorthToEast.9
#  redID: VehicleFlowNorthToEast.9   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 20 VehicleFlowNorthToSouth.10
#  redID: VehicleFlowNorthToSouth.10   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 21 VehicleFlowNorthToWest.17
#  redID: VehicleFlowNorthToWest.17   (max(timeList) - min(timeList))<3
# genSamples 22 BusFlowNorthSouth0.1
#  redID: BusFlowNorthSouth0.1   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 23 VehicleFlowNorthToWest.18
#  redID: VehicleFlowNorthToWest.18   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 24 VehicleFlowNorthToWest.19
#  redID: VehicleFlowNorthToWest.19   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 25 VehicleFlowNorthToSouth.12
#  redID: VehicleFlowNorthToSouth.12   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 26 VehicleFlowNorthToSouth.13
#  redID: VehicleFlowNorthToSouth.13   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 27 VehicleFlowNorthToWest.21
#  redID: VehicleFlowNorthToWest.21   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 28 VehicleFlowNorthToWest.22
#  redID: VehicleFlowNorthToWest.22   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 29 VehicleFlowNorthToSouth.14
#  redID: VehicleFlowNorthToSouth.14   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 30 VehicleFlowNorthToEast.14
#  redID: VehicleFlowNorthToEast.14   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 31 VehicleFlowNorthToWest.24
#  redID: VehicleFlowNorthToWest.24   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 32 VehicleFlowNorthToWest.25
#  redID: VehicleFlowNorthToWest.25   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 33 VehicleFlowNorthToEast.15
#  redID: VehicleFlowNorthToEast.15   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 34 VehicleFlowNorthToEast.16
#  redID: VehicleFlowNorthToEast.16   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 35 VehicleFlowNorthToWest.27
#  redID: VehicleFlowNorthToWest.27   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 36 VehicleFlowNorthToWest.28
#  redID: VehicleFlowNorthToWest.28   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 37 VehicleFlowNorthToEast.17
#  redID: VehicleFlowNorthToEast.17   (max(timeList) - min(timeList))<3
# genSamples 38 VehicleFlowNorthToWest.30
#  redID: VehicleFlowNorthToWest.30   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 39 VehicleFlowNorthToSouth.19
#  redID: VehicleFlowNorthToSouth.19   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 40 VehicleFlowNorthToWest.31
#  redID: VehicleFlowNorthToWest.31   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 41 VehicleFlowNorthToSouth.20
#  redID: VehicleFlowNorthToSouth.20   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 42 VehicleFlowNorthToWest.33
#  redID: VehicleFlowNorthToWest.33   (max(timeList) - min(timeList))<3
# genSamples 43 VehicleFlowNorthToEast.20
#  redID: VehicleFlowNorthToEast.20   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 44 VehicleFlowNorthToWest.34
#  redID: VehicleFlowNorthToWest.34   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 45 VehicleFlowNorthToEast.21
#  redID: VehicleFlowNorthToEast.21   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 46 VehicleFlowNorthToEast.22
#  redID: VehicleFlowNorthToEast.22   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 47 VehicleFlowNorthToWest.37
#  redID: VehicleFlowNorthToWest.37   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 48 VehicleFlowNorthToWest.38
#  redID: VehicleFlowNorthToWest.38   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 49 VehicleFlowNorthToEast.23
#  redID: VehicleFlowNorthToEast.23   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 50 VehicleFlowNorthToEast1.0
#  redID: VehicleFlowNorthToEast1.0   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 51 VehicleFlowNorthToWest1.0
#  redID: VehicleFlowNorthToWest1.0   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 52 VehicleFlowNorthToWest.41
#  redID: VehicleFlowNorthToWest.41   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 53 VehicleFlowNorthToWest1.2
#  redID: VehicleFlowNorthToWest1.2   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 54 VehicleFlowNorthToWest1.4
#  redID: VehicleFlowNorthToWest1.4   (max(timeList) - min(timeList))<3
# genSamples 55 VehicleFlowNorthToEast1.2
#  redID: VehicleFlowNorthToEast1.2   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 56 VehicleFlowNorthToWest1.5
#  redID: VehicleFlowNorthToWest1.5   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 57 VehicleFlowNorthToWest1.7
#  redID: VehicleFlowNorthToWest1.7   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 58 VehicleFlowNorthToWest1.8
#  redID: VehicleFlowNorthToWest1.8   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 59 VehicleFlowNorthToSouth1.3
#  redID: VehicleFlowNorthToSouth1.3   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 60 VehicleFlowNorthToEast1.4
#  redID: VehicleFlowNorthToEast1.4   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 61 VehicleFlowNorthToWest1.10
#  redID: VehicleFlowNorthToWest1.10   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 62 VehicleFlowNorthToWest1.12
#  redID: VehicleFlowNorthToWest1.12   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 63 VehicleFlowNorthToWest1.13
#  redID: VehicleFlowNorthToWest1.13   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 64 VehicleFlowNorthToEast1.6
#  redID: VehicleFlowNorthToEast1.6   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 65 VehicleFlowNorthToWest1.15
#  redID: VehicleFlowNorthToWest1.15   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 66 VehicleFlowNorthToWest1.16
#  redID: VehicleFlowNorthToWest1.16   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 67 VehicleFlowNorthToSouth1.6
#  redID: VehicleFlowNorthToSouth1.6   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 68 VehicleFlowNorthToWest1.18
#  redID: VehicleFlowNorthToWest1.18   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 69 VehicleFlowNorthToSouth1.7
#  redID: VehicleFlowNorthToSouth1.7   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 70 VehicleFlowNorthToWest1.20
#  redID: VehicleFlowNorthToWest1.20   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 71 VehicleFlowNorthToWest1.21
#  redID: VehicleFlowNorthToWest1.21   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 72 BusFlowNorthSouth.1
#  redID: BusFlowNorthSouth.1   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 73 VehicleFlowNorthToWest1.23
#  redID: VehicleFlowNorthToWest1.23   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 74 VehicleFlowNorthToEast1.10
#  redID: VehicleFlowNorthToEast1.10   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 75 VehicleFlowNorthToWest1.25
#  redID: VehicleFlowNorthToWest1.25   (max(timeList) - min(timeList))<3
# genSamples 76 VehicleFlowNorthToWest1.26
#  redID: VehicleFlowNorthToWest1.26   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 77 VehicleFlowNorthToSouth1.10
#  redID: VehicleFlowNorthToSouth1.10   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 78 VehicleFlowNorthToWest1.28
#  redID: VehicleFlowNorthToWest1.28   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 79 VehicleFlowNorthToWest1.29
#  redID: VehicleFlowNorthToWest1.29   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 80 VehicleFlowNorthToEast1.12
#  redID: VehicleFlowNorthToEast1.12   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 81 VehicleFlowNorthToWest1.31
#  redID: VehicleFlowNorthToWest1.31   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 82 VehicleFlowNorthToWest1.33
#  redID: VehicleFlowNorthToWest1.33   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 83 VehicleFlowNorthToSouth1.12
#  redID: VehicleFlowNorthToSouth1.12   (max(timeList) - min(timeList))<3
# genSamples 84 VehicleFlowNorthToWest1.34
#  redID: VehicleFlowNorthToWest1.34   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 85 VehicleFlowNorthToEast1.14
#  redID: VehicleFlowNorthToEast1.14   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 86 VehicleFlowNorthToSouth1.13
#  redID: VehicleFlowNorthToSouth1.13   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 87 VehicleFlowNorthToWest1.36
#  redID: VehicleFlowNorthToWest1.36   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 88 VehicleFlowNorthToEast1.15
#  redID: VehicleFlowNorthToEast1.15   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 89 VehicleFlowNorthToWest1.38
#  redID: VehicleFlowNorthToWest1.38   (max(timeList) - min(timeList))<3
# genSamples 90 VehicleFlowNorthToSouth1.14
#  redID: VehicleFlowNorthToSouth1.14   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 91 VehicleFlowNorthToWest1.39
#  redID: VehicleFlowNorthToWest1.39   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 92 VehicleFlowNorthToWest1.41
#  redID: VehicleFlowNorthToWest1.41   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 93 VehicleFlowNorthToWest1.42
#  redID: VehicleFlowNorthToWest1.42   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 94 VehicleFlowNorthToEast1.17
#  redID: VehicleFlowNorthToEast1.17   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 95 VehicleFlowNorthToWest1.44
#  redID: VehicleFlowNorthToWest1.44   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 96 VehicleFlowNorthToSouth1.16
#  redID: VehicleFlowNorthToSouth1.16   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 97 VehicleFlowNorthToWest1.46
#  redID: VehicleFlowNorthToWest1.46   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 98 BusFlowNorthSouth1.0
#  redID: BusFlowNorthSouth1.0   (max(timeList) - min(timeList))<3
# genSamples 99 VehicleFlowNorthToWest2.1
#  redID: VehicleFlowNorthToWest2.1   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 100 VehicleFlowNorthToEast2.1
#  redID: VehicleFlowNorthToEast2.1   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 101 VehicleFlowNorthToWest2.3
#  redID: VehicleFlowNorthToWest2.3   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 102 VehicleFlowNorthToWest2.5
#  redID: VehicleFlowNorthToWest2.5   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 103 VehicleFlowNorthToEast2.2
#  redID: VehicleFlowNorthToEast2.2   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 104 VehicleFlowNorthToSouth2.2
#  redID: VehicleFlowNorthToSouth2.2   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 105 VehicleFlowNorthToWest2.7
#  redID: VehicleFlowNorthToWest2.7   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 106 VehicleFlowNorthToWest2.9
#  redID: VehicleFlowNorthToWest2.9   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 107 VehicleFlowNorthToWest2.11
#  redID: VehicleFlowNorthToWest2.11   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 108 VehicleFlowNorthToEast2.5
#  redID: VehicleFlowNorthToEast2.5   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 109 VehicleFlowNorthToWest2.13
#  redID: VehicleFlowNorthToWest2.13   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 110 VehicleFlowNorthToWest2.15
#  redID: VehicleFlowNorthToWest2.15   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 111 VehicleFlowNorthToEast2.6
#  redID: VehicleFlowNorthToEast2.6   (max(timeList) - min(timeList))<3
# genSamples 112 VehicleFlowNorthToSouth2.5
#  redID: VehicleFlowNorthToSouth2.5   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 113 VehicleFlowNorthToWest2.17
#  redID: VehicleFlowNorthToWest2.17   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 114 VehicleFlowNorthToWest2.19
#  redID: VehicleFlowNorthToWest2.19   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 115 VehicleFlowNorthToEast2.8
#  redID: VehicleFlowNorthToEast2.8   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 116 VehicleFlowNorthToWest2.21
#  redID: VehicleFlowNorthToWest2.21   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 117 VehicleFlowNorthToEast2.9
#  redID: VehicleFlowNorthToEast2.9   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 118 VehicleFlowNorthToWest2.23
#  redID: VehicleFlowNorthToWest2.23   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 119 VehicleFlowNorthToWest2.25
#  redID: VehicleFlowNorthToWest2.25   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 120 BusFlowNorthSouth1.1
#  redID: BusFlowNorthSouth1.1   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 121 VehicleFlowNorthToWest2.27
#  redID: VehicleFlowNorthToWest2.27   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 122 VehicleFlowNorthToEast2.11
#  redID: VehicleFlowNorthToEast2.11   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 123 VehicleFlowNorthToWest2.29
#  redID: VehicleFlowNorthToWest2.29   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 124 VehicleFlowNorthToWest2.30
#  redID: VehicleFlowNorthToWest2.30   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 125 VehicleFlowNorthToEast2.12
#  redID: VehicleFlowNorthToEast2.12   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 126 VehicleFlowNorthToWest2.32
#  redID: VehicleFlowNorthToWest2.32   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 127 VehicleFlowNorthToSouth2.10
#  redID: VehicleFlowNorthToSouth2.10   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 128 VehicleFlowNorthToWest2.34
#  redID: VehicleFlowNorthToWest2.34   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 129 VehicleFlowNorthToWest2.35
#  redID: VehicleFlowNorthToWest2.35   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 130 VehicleFlowNorthToWest2.36
#  redID: VehicleFlowNorthToWest2.36   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 131 VehicleFlowNorthToSouth2.11
#  redID: VehicleFlowNorthToSouth2.11   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 132 VehicleFlowNorthToWest2.38
#  redID: VehicleFlowNorthToWest2.38   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 133 VehicleFlowNorthToEast2.15
#  redID: VehicleFlowNorthToEast2.15   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 134 VehicleFlowNorthToWest2.40
#  redID: VehicleFlowNorthToWest2.40   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 135 VehicleFlowNorthToEast2.16
#  redID: VehicleFlowNorthToEast2.16   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 136 VehicleFlowNorthToWest2.42
#  redID: VehicleFlowNorthToWest2.42   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 137 VehicleFlowNorthToSouth2.13
#  redID: VehicleFlowNorthToSouth2.13   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 138 VehicleFlowNorthToWest2.44
#  redID: VehicleFlowNorthToWest2.44   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 139 VehicleFlowNorthToWest2.45
#  redID: VehicleFlowNorthToWest2.45   (max(timeList) - min(timeList))<3
# genSamples 140 VehicleFlowNorthToEast2.18
#  redID: VehicleFlowNorthToEast2.18   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 141 VehicleFlowNorthToWest2.46
#  redID: VehicleFlowNorthToWest2.46   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 142 VehicleFlowNorthToWest2.48
#  redID: VehicleFlowNorthToWest2.48   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 143 VehicleFlowNorthToEast2.19
#  redID: VehicleFlowNorthToEast2.19   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 144 VehicleFlowNorthToWest2.50
#  redID: VehicleFlowNorthToWest2.50   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 145 VehicleFlowNorthToEast2.20
#  redID: VehicleFlowNorthToEast2.20   (max(timeList) - min(timeList))<3
# genSamples 146 VehicleFlowNorthToWest2.52
#  redID: VehicleFlowNorthToWest2.52   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 147 VehicleFlowNorthToSouth2.16
#  redID: VehicleFlowNorthToSouth2.16   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 148 VehicleFlowNorthToWest2.54
#  redID: VehicleFlowNorthToWest2.54   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 149 BusFlowNorthSouth2.0
#  redID: BusFlowNorthSouth2.0   (max(timeList) - min(timeList))<3
# genSamples 150 VehicleFlowNorthToWest3.1
#  redID: VehicleFlowNorthToWest3.1   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 151 VehicleFlowNorthToWest3.2
#  redID: VehicleFlowNorthToWest3.2   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 152 VehicleFlowNorthToSouth3.1
#  redID: VehicleFlowNorthToSouth3.1   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 153 VehicleFlowNorthToWest3.4
#  redID: VehicleFlowNorthToWest3.4   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 154 VehicleFlowNorthToSouth3.2
#  redID: VehicleFlowNorthToSouth3.2   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 155 VehicleFlowNorthToWest3.5
#  redID: VehicleFlowNorthToWest3.5   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 156 VehicleFlowNorthToWest3.7
#  redID: VehicleFlowNorthToWest3.7   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 157 VehicleFlowNorthToWest3.8
#  redID: VehicleFlowNorthToWest3.8   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 158 VehicleFlowNorthToSouth3.4
#  redID: VehicleFlowNorthToSouth3.4   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 159 VehicleFlowNorthToWest3.10
#  redID: VehicleFlowNorthToWest3.10   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 160 VehicleFlowNorthToEast3.7
#  redID: VehicleFlowNorthToEast3.7   (max(timeList) - min(timeList))<3
# genSamples 161 VehicleFlowNorthToWest3.11
#  redID: VehicleFlowNorthToWest3.11   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 162 VehicleFlowNorthToEast3.8
#  redID: VehicleFlowNorthToEast3.8   (max(timeList) - min(timeList))<3
# genSamples 163 VehicleFlowNorthToSouth3.6
#  redID: VehicleFlowNorthToSouth3.6   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 164 VehicleFlowNorthToWest3.13
#  redID: VehicleFlowNorthToWest3.13   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 165 VehicleFlowNorthToWest3.14
#  redID: VehicleFlowNorthToWest3.14   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 166 VehicleFlowNorthToSouth3.7
#  redID: VehicleFlowNorthToSouth3.7   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 167 VehicleFlowNorthToWest3.16
#  redID: VehicleFlowNorthToWest3.16   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 168 VehicleFlowNorthToEast3.11
#  redID: VehicleFlowNorthToEast3.11   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 169 VehicleFlowNorthToWest3.17
#  redID: VehicleFlowNorthToWest3.17   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 170 VehicleFlowNorthToEast3.12
#  redID: VehicleFlowNorthToEast3.12   (max(timeList) - min(timeList))<3
# genSamples 171 VehicleFlowNorthToSouth3.9
#  redID: VehicleFlowNorthToSouth3.9   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 172 VehicleFlowNorthToWest3.19
#  redID: VehicleFlowNorthToWest3.19   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 173 VehicleFlowNorthToWest3.20
#  redID: VehicleFlowNorthToWest3.20   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 174 VehicleFlowNorthToEast3.14
#  redID: VehicleFlowNorthToEast3.14   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 175 VehicleFlowNorthToWest3.22
#  redID: VehicleFlowNorthToWest3.22   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 176 VehicleFlowNorthToWest3.23
#  redID: VehicleFlowNorthToWest3.23   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 177 VehicleFlowNorthToEast3.16
#  redID: VehicleFlowNorthToEast3.16   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 178 VehicleFlowNorthToSouth3.12
#  redID: VehicleFlowNorthToSouth3.12   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 179 VehicleFlowNorthToWest3.25
#  redID: VehicleFlowNorthToWest3.25   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 180 VehicleFlowNorthToWest3.26
#  redID: VehicleFlowNorthToWest3.26   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 181 VehicleFlowNorthToEast3.18
#  redID: VehicleFlowNorthToEast3.18   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 182 VehicleFlowNorthToEast3.19
#  redID: VehicleFlowNorthToEast3.19   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 183 VehicleFlowNorthToWest3.28
#  redID: VehicleFlowNorthToWest3.28   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 184 VehicleFlowNorthToSouth3.14
#  redID: VehicleFlowNorthToSouth3.14   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 185 VehicleFlowNorthToWest3.29
#  redID: VehicleFlowNorthToWest3.29   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 186 VehicleFlowNorthToEast3.21
#  redID: VehicleFlowNorthToEast3.21   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 187 VehicleFlowNorthToWest3.31
#  redID: VehicleFlowNorthToWest3.31   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 188 VehicleFlowNorthToWest3.32
#  redID: VehicleFlowNorthToWest3.32   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 189 VehicleFlowNorthToEast3.22
#  redID: VehicleFlowNorthToEast3.22   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 190 VehicleFlowNorthToEast3.23
#  redID: VehicleFlowNorthToEast3.23   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 191 VehicleFlowNorthToWest3.34
#  redID: VehicleFlowNorthToWest3.34   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 192 VehicleFlowNorthToSouth3.17
#  redID: VehicleFlowNorthToSouth3.17   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 193 VehicleFlowNorthToWest3.35
#  redID: VehicleFlowNorthToWest3.35   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 194 VehicleFlowNorthToEast3.25
#  redID: VehicleFlowNorthToEast3.25   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 195 VehicleFlowNorthToWest3.37
#  redID: VehicleFlowNorthToWest3.37   (max(timeList) - min(timeList))<3
# genSamples 196 VehicleFlowNorthToWest3.38
#  redID: VehicleFlowNorthToWest3.38   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 197 VehicleFlowNorthToEast3.26
#  redID: VehicleFlowNorthToEast3.26   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 198 VehicleFlowNorthToEast3.27
#  redID: VehicleFlowNorthToEast3.27   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 199 VehicleFlowNorthToWest3.40
#  redID: VehicleFlowNorthToWest3.40   (max(timeList) - min(timeList))<3
# genSamples 200 VehicleFlowNorthToWest4.0
#  redID: VehicleFlowNorthToWest4.0   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 201 VehicleFlowNorthToWest4.1
#  redID: VehicleFlowNorthToWest4.1   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 202 VehicleFlowNorthToWest4.2
#  redID: VehicleFlowNorthToWest4.2   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 203 VehicleFlowNorthToEast4.1
#  redID: VehicleFlowNorthToEast4.1   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 204 VehicleFlowNorthToWest4.4
#  redID: VehicleFlowNorthToWest4.4   (max(timeList) - min(timeList))<3
# genSamples 205 VehicleFlowNorthToEast4.2
#  redID: VehicleFlowNorthToEast4.2   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 206 VehicleFlowNorthToWest4.5
#  redID: VehicleFlowNorthToWest4.5   maxLanePos1 != maxLanePos 96.57 96.25
# genSamples 207 VehicleFlowNorthToWest4.7
#  redID: VehicleFlowNorthToWest4.7   (max(timeList) - min(timeList))<3
# genSamples 208 VehicleFlowNorthToWest4.8
# ...
# genSamples 131 VehicleFlowWestToEast3.61
#  redID: VehicleFlowWestToEast3.61   (max(timeList) - min(timeList))<3
# genSamples 132 VehicleFlowWestToEast4_0.6
#  redID: VehicleFlowWestToEast4_0.6   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 133 VehicleFlowWestToNorth4.8
#  redID: VehicleFlowWestToNorth4.8   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 134 VehicleFlowWestToEast4.12
#  redID: VehicleFlowWestToEast4.12   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 135 VehicleFlowWestToEast4_0.15
#  redID: VehicleFlowWestToEast4_0.15   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 136 VehicleFlowSouthToNorth4.8
#  redID: VehicleFlowSouthToNorth4.8   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 137 VehicleFlowWestToNorth4.10
#  redID: VehicleFlowWestToNorth4.10   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 138 VehicleFlowWestToEast4_0.17
#  redID: VehicleFlowWestToEast4_0.17   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 139 VehicleFlowWestToEast4.14
#  redID: VehicleFlowWestToEast4.14   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 140 VehicleFlowWestToNorth4.13
#  redID: VehicleFlowWestToNorth4.13   (max(timeList) - min(timeList))<3
# genSamples 141 VehicleFlowWestToNorth4.14
#  redID: VehicleFlowWestToNorth4.14   (max(timeList) - min(timeList))<3
# genSamples 142 VehicleFlowNorthToEast4.5
#  redID: VehicleFlowNorthToEast4.5   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 143 VehicleFlowWestToEast4.24
#  redID: VehicleFlowWestToEast4.24   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 144 VehicleFlowWestToEast4.28
#  redID: VehicleFlowWestToEast4.28   (max(timeList) - min(timeList))<3
# genSamples 145 VehicleFlowWestToEast4_0.33
#  redID: VehicleFlowWestToEast4_0.33   (max(timeList) - min(timeList))<3
# genSamples 146 VehicleFlowSouthToNorth4.16
#  redID: VehicleFlowSouthToNorth4.16   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 147 VehicleFlowSouthToEast4.14
#  redID: VehicleFlowSouthToEast4.14   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 148 VehicleFlowSouthToWest4.12
#  redID: VehicleFlowSouthToWest4.12   (max(timeList) - min(timeList))<3
# genSamples 149 VehicleFlowWestToNorth4.31
#  redID: VehicleFlowWestToNorth4.31   (max(timeList) - min(timeList))<3
# genSamples 150 VehicleFlowWestToNorth4.33
#  redID: VehicleFlowWestToNorth4.33   (max(timeList) - min(timeList))<3
# genSamples 151 VehicleFlowWestToNorth4.34
#  redID: VehicleFlowWestToNorth4.34   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 152 VehicleFlowWestToEast4.43
#  redID: VehicleFlowWestToEast4.43   (max(timeList) - min(timeList))<3
# genSamples 153 VehicleFlowSouthToNorth4.24
#  redID: VehicleFlowSouthToNorth4.24   (max(timeList) - min(timeList))<3
# genSamples 154 VehicleFlowWestToNorth4.49
#  redID: VehicleFlowWestToNorth4.49   (max(timeList) - min(timeList))<3
# genSamples 155 VehicleFlowWestToNorth4.44
#  redID: VehicleFlowWestToNorth4.44   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 156 VehicleFlowWestToEast4_0.57
#  redID: VehicleFlowWestToEast4_0.57   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 157 VehicleFlowWestToEast4_0.62
#  redID: VehicleFlowWestToEast4_0.62   (max(timeList) - min(timeList))<3
# genSamples 158 VehicleFlowWestToEast4_0.61
#  redID: VehicleFlowWestToEast4_0.61   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 159 VehicleFlowWestToNorth4.58
#  redID: VehicleFlowWestToNorth4.58   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 160 VehicleFlowWestToEast4_0.67
#  redID: VehicleFlowWestToEast4_0.67   (max(timeList) - min(timeList))<3
# genSamples 161 VehicleFlowWestToNorth4.59
#  redID: VehicleFlowWestToNorth4.59   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 162 VehicleFlowWestToEast4_0.73
#  redID: VehicleFlowWestToEast4_0.73   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 163 VehicleFlowWestToNorth4.64
#  redID: VehicleFlowWestToNorth4.64   (max(timeList) - min(timeList))<3
# genSamples 164 VehicleFlowSouthToEast4.28
#  redID: VehicleFlowSouthToEast4.28   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 165 VehicleFlowWestToEast4_0.81
#  redID: VehicleFlowWestToEast4_0.81   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 166 VehicleFlowWestToEast4_0.85
#  redID: VehicleFlowWestToEast4_0.85   (max(timeList) - min(timeList))<3
# genSamples 167 VehicleFlowWestToEast4.79
#  redID: VehicleFlowWestToEast4.79   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 168 VehicleFlowSouthToWest4.29
#  redID: VehicleFlowSouthToWest4.29   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 169 VehicleFlowWestToEast6_0.6
#  redID: VehicleFlowWestToEast6_0.6   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 170 VehicleFlowWestToEast6_0.7
#  redID: VehicleFlowWestToEast6_0.7   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 171 VehicleFlowWestToNorth4.77
#  redID: VehicleFlowWestToNorth4.77   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 172 VehicleFlowWestToEast6.5
#  redID: VehicleFlowWestToEast6.5   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 173 VehicleFlowSouthToEast4.38
#  redID: VehicleFlowSouthToEast4.38   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 174 VehicleFlowWestToEast6.9
#  redID: VehicleFlowWestToEast6.9   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 175 VehicleFlowWestToEast6.14
#  redID: VehicleFlowWestToEast6.14   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 176 VehicleFlowSouthToNorth6.1
#  redID: VehicleFlowSouthToNorth6.1   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 177 VehicleFlowSouthToNorth6.3
#  redID: VehicleFlowSouthToNorth6.3   (max(timeList) - min(timeList))<3
# genSamples 178 VehicleFlowSouthToEast6.4
#  redID: VehicleFlowSouthToEast6.4   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 179 VehicleFlowWestToEast6_0.30
#  redID: VehicleFlowWestToEast6_0.30   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 180 VehicleFlowWestToEast6_0.26
#  redID: VehicleFlowWestToEast6_0.26   (max(timeList) - min(timeList))<3
# genSamples 181 VehicleFlowWestToEast6.30
#  redID: VehicleFlowWestToEast6.30   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 182 VehicleFlowWestToEast6.32
#  redID: VehicleFlowWestToEast6.32   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 183 VehicleFlowWestToNorth6.18
#  redID: VehicleFlowWestToNorth6.18   (max(timeList) - min(timeList))<3
# genSamples 184 VehicleFlowWestToEast6_0.39
#  redID: VehicleFlowWestToEast6_0.39   (max(timeList) - min(timeList))<3
# genSamples 185 VehicleFlowWestToNorth6.20
#  redID: VehicleFlowWestToNorth6.20   (max(timeList) - min(timeList))<3
# genSamples 186 VehicleFlowWestToEast6.37
#  redID: VehicleFlowWestToEast6.37   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 187 VehicleFlowSouthToNorth6.14
#  redID: VehicleFlowSouthToNorth6.14   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 188 VehicleFlowNorthToEast6.11
#  redID: VehicleFlowNorthToEast6.11   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 189 VehicleFlowNorthToEast6.9
#  redID: VehicleFlowNorthToEast6.9   (max(timeList) - min(timeList))<3
# genSamples 190 VehicleFlowSouthToEast6.16
#  redID: VehicleFlowSouthToEast6.16   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 191 VehicleFlowWestToEast6_0.63
#  redID: VehicleFlowWestToEast6_0.63   (max(timeList) - min(timeList))<3
# genSamples 192 VehicleFlowWestToNorth6.34
#  redID: VehicleFlowWestToNorth6.34   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 193 VehicleFlowSouthToNorth6.27
#  redID: VehicleFlowSouthToNorth6.27   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 194 VehicleFlowWestToEast6.63
#  redID: VehicleFlowWestToEast6.63   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 195 VehicleFlowWestToEast6.64
#  redID: VehicleFlowWestToEast6.64   (max(timeList) - min(timeList))<3
# genSamples 196 VehicleFlowWestToEast6_0.71
#  redID: VehicleFlowWestToEast6_0.71   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 197 VehicleFlowSouthToEast6.22
#  redID: VehicleFlowSouthToEast6.22   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 198 VehicleFlowSouthToWest6.34
#  redID: VehicleFlowSouthToWest6.34   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 199 VehicleFlowSouthToNorth6.37
#  redID: VehicleFlowSouthToNorth6.37   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 200 VehicleFlowWestToEast6_0.83
#  redID: VehicleFlowWestToEast6_0.83   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 201 VehicleFlowWestToNorth6.45
#  redID: VehicleFlowWestToNorth6.45   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 202 VehicleFlowSouthToNorth6.43
#  redID: VehicleFlowSouthToNorth6.43   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 203 VehicleFlowWestToEast5.5
#  redID: VehicleFlowWestToEast5.5   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 204 BusFlowSouthNorth5.0
#  redID: BusFlowSouthNorth5.0   (max(timeList) - min(timeList))<3
# genSamples 205 VehicleFlowSouthToEast5.0
#  redID: VehicleFlowSouthToEast5.0   (max(timeList) - min(timeList))<3
# genSamples 206 VehicleFlowWestToEast5_0.16
#  redID: VehicleFlowWestToEast5_0.16   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 207 VehicleFlowNorthToEast5.5
#  redID: VehicleFlowNorthToEast5.5   (max(timeList) - min(timeList))<3
# genSamples 208 VehicleFlowWestToEast5_0.21
#  redID: VehicleFlowWestToEast5_0.21   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 209 VehicleFlowWestToEast5_0.22
#  redID: VehicleFlowWestToEast5_0.22   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 210 VehicleFlowWestToEast5_0.30
#  redID: VehicleFlowWestToEast5_0.30   (max(timeList) - min(timeList))<3
# genSamples 211 VehicleFlowWestToEast5_0.33
#  redID: VehicleFlowWestToEast5_0.33   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 212 VehicleFlowWestToEast5_0.36
#  redID: VehicleFlowWestToEast5_0.36   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 213 VehicleFlowWestToEast5_0.39
#  redID: VehicleFlowWestToEast5_0.39   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 214 VehicleFlowWestToNorth5.22
#  redID: VehicleFlowWestToNorth5.22   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 215 VehicleFlowSouthToEast5.18
#  redID: VehicleFlowSouthToEast5.18   (max(timeList) - min(timeList))<3
# genSamples 216 VehicleFlowWestToEast5_0.50
#  redID: VehicleFlowWestToEast5_0.50   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 217 VehicleFlowWestToEast5_0.49
#  redID: VehicleFlowWestToEast5_0.49   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 218 VehicleFlowWestToNorth5.29
#  redID: VehicleFlowWestToNorth5.29   (max(timeList) - min(timeList))<3
# genSamples 219 VehicleFlowWestToEast5_0.56
#  redID: VehicleFlowWestToEast5_0.56   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 220 VehicleFlowWestToEast5.50
#  redID: VehicleFlowWestToEast5.50   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 221 VehicleFlowSouthToNorth5.21
#  redID: VehicleFlowSouthToNorth5.21   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 222 VehicleFlowSouthToWest5.21
#  redID: VehicleFlowSouthToWest5.21   (max(timeList) - min(timeList))<3
# genSamples 223 VehicleFlowWestToNorth5.34
#  redID: VehicleFlowWestToNorth5.34   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 224 VehicleFlowWestToNorth5.36
#  redID: VehicleFlowWestToNorth5.36   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 225 VehicleFlowWestToNorth5.37
#  redID: VehicleFlowWestToNorth5.37   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 226 VehicleFlowWestToEast5.63
#  redID: VehicleFlowWestToEast5.63   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 227 VehicleFlowWestToEast5_0.65
#  redID: VehicleFlowWestToEast5_0.65   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 228 VehicleFlowWestToEast5.64
#  redID: VehicleFlowWestToEast5.64   (max(timeList) - min(timeList))<3
# genSamples 229 VehicleFlowSouthToEast5.30
#  redID: VehicleFlowSouthToEast5.30   (max(timeList) - min(timeList))<3
# genSamples 230 VehicleFlowWestToEast5_0.79
#  redID: VehicleFlowWestToEast5_0.79   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 231 VehicleFlowWestToEast5_0.76
#  redID: VehicleFlowWestToEast5_0.76   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 232 VehicleFlowWestToEast5_0.83
#  redID: VehicleFlowWestToEast5_0.83   (max(timeList) - min(timeList))<3
# genSamples 233 VehicleFlowSouthToEast5.36
#  redID: VehicleFlowSouthToEast5.36   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 234 VehicleFlowWestToEast5.87
#  redID: VehicleFlowWestToEast5.87   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 235 VehicleFlowWestToEast5.91
#  redID: VehicleFlowWestToEast5.91   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 236 VehicleFlowWestToEast7.4
#  redID: VehicleFlowWestToEast7.4   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 237 VehicleFlowWestToEast7_0.11
#  redID: VehicleFlowWestToEast7_0.11   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 238 VehicleFlowWestToEast7_0.14
#  redID: VehicleFlowWestToEast7_0.14   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 239 VehicleFlowWestToEast7_0.16
#  redID: VehicleFlowWestToEast7_0.16   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 240 VehicleFlowWestToNorth7.6
#  redID: VehicleFlowWestToNorth7.6   (max(timeList) - min(timeList))<3
# genSamples 241 VehicleFlowWestToEast7_0.25
#  redID: VehicleFlowWestToEast7_0.25   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 242 VehicleFlowWestToEast7.20
#  redID: VehicleFlowWestToEast7.20   (max(timeList) - min(timeList))<3
# genSamples 243 VehicleFlowWestToEast7_0.28
#  redID: VehicleFlowWestToEast7_0.28   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 244 VehicleFlowNorthToEast7.8
#  redID: VehicleFlowNorthToEast7.8   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 245 VehicleFlowWestToEast7_0.38
#  redID: VehicleFlowWestToEast7_0.38   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 246 VehicleFlowWestToEast7_0.40
#  redID: VehicleFlowWestToEast7_0.40   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 247 VehicleFlowWestToEast7_0.46
#  redID: VehicleFlowWestToEast7_0.46   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 248 VehicleFlowWestToEast7.43
#  redID: VehicleFlowWestToEast7.43   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 249 VehicleFlowWestToEast7.46
#  redID: VehicleFlowWestToEast7.46   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 250 VehicleFlowWestToEast7_0.63
#  redID: VehicleFlowWestToEast7_0.63   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 251 VehicleFlowWestToEast7_0.65
#  redID: VehicleFlowWestToEast7_0.65   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 252 VehicleFlowWestToEast7.64
#  redID: VehicleFlowWestToEast7.64   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 253 VehicleFlowWestToEast7.71
#  redID: VehicleFlowWestToEast7.71   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 254 VehicleFlowSouthToEast7.27
#  redID: VehicleFlowSouthToEast7.27   (max(timeList) - min(timeList))<3
# genSamples 255 VehicleFlowNorthToEast7.20
#  redID: VehicleFlowNorthToEast7.20   maxLanePos1 != maxLanePos 8.64 8.61
# genSamples 256 VehicleFlowWestToEast7_0.87
#  redID: VehicleFlowWestToEast7_0.87   maxLanePos1 != maxLanePos 8.64 8.61
# len(redVehs): 2001
# len(samplesAll): 0
#
# laneIndex is 200,nameID is -1340#3_0
#
# laneIndex is 201,nameID is :2470886209_0_0
#
# laneIndex is 202,nameID is :431399507_2_0
# analyzingRedVehAtCurLane  0 VehicleFlowEastToEast4.0
# genSamples 0 VehicleFlowEastToEast4.0
#  redID: VehicleFlowEastToEast4.0   (max(timeList) - min(timeList))<3
# len(redVehs): 1
# len(samplesAll): 0
#
# laneIndex is 203,nameID is -1278#0_1
# analyzingRedVehAtCurLane  0 VehicleFlowEastToEast2.0
# analyzingRedVehAtCurLane  1 VehicleFlowEastToEast4.0
# analyzingRedVehAtCurLane  2 VehicleFlowEastToEast5.0
# analyzingRedVehAtCurLane  3 VehicleFlowEastToEast5.1
# analyzingRedVehAtCurLane  4 VehicleFlowEastToEast7.0
# genSamples 0 VehicleFlowEastToEast2.0
#  redID: VehicleFlowEastToEast2.0   (max(timeList) - min(timeList))<3
# genSamples 1 VehicleFlowEastToEast4.0
#  redID: VehicleFlowEastToEast4.0   (max(timeList) - min(timeList))<3
# genSamples 2 VehicleFlowEastToEast5.0
#  redID: VehicleFlowEastToEast5.0   (max(timeList) - min(timeList))<3
# genSamples 3 VehicleFlowEastToEast5.1
#  redID: VehicleFlowEastToEast5.1   (max(timeList) - min(timeList))<3
# genSamples 4 VehicleFlowEastToEast7.0
#  redID: VehicleFlowEastToEast7.0   (max(timeList) - min(timeList))<3
# len(redVehs): 5
# len(samplesAll): 0
#
# laneIndex is 204,nameID is :301266367_2_0
#
# laneIndex is 205,nameID is :-318_1_0
#
# laneIndex is 206,nameID is -1282#0_1
#
# laneIndex is 207,nameID is :-584_1_1
#
# laneIndex is 208,nameID is nan
# 	zip warning: name not matched: ./trainData/france_0_allSamples1.csv
#
# zip error: Nothing to do! (./france_0_allSamples1.zip)

# %%
# 尝试把前面几秒的时间进行合成
import pandas as pd

filename = "../trainData/"+"france_0_allSamples1.csv"
df = pd.read_csv(filename, sep=',')
df = df.drop_duplicates()
samplesAll = []
# print(df.info)

IDList = df['vehID'].unique()  # 枚举获得每一辆车
for iVeh, curVehID in enumerate(IDList):  # 枚举获得每一辆车

    # if iVeh >100:#测试用
    #    break

    print(iVeh, curVehID)
    df1 = df[df.vehID == curVehID]  # 获得只含有当前车的样本

    laneList = df1.vehLaneID.unique()
    for iLane, curLaneID in enumerate(laneList):  # 枚举获得每一辆车所属的edge

        '''
        edgeStr=curLaneID.partition("_")
        edgeStr=edgeStr[0]
        resault = df1['vehLaneID'].str.contains(edgeStr)
        resault.fillna(value=False,inplace = True)
        df2 = df1[resault]#获得只含有当前edge的样本 
        '''

        df2 = df1[df1['vehLaneID'] == curLaneID]  # 获得只含有当前edge的样本

        timeList = df2.redLightTime.values  # 存在时间
        duration = max(timeList) - min(timeList)

        if duration < 3:  # 持续时间小于3秒的不要
            continue

        df2 = df2.sort_values(by='redLightTime', ascending=False)  # 提取持续的时间段

        sampleLen = 50
        # print(df2.redLightTime.values) #样本中有很多重复样本，因为我做了重采样
        # input()
        for iTime, curTime in enumerate(df2.redLightTime.values):
            # 样本中有很多重复样本，因为我做了重采样
            if iTime == 0:
                sampleNow = df2[df2.redLightTime == curTime].values.tolist()
                sampleNow = sampleNow[0]  # 样本中有很多重复样本，因为我做了重采样。所以只用第一个
                sampleLast = sampleNow.copy()
                sampleNow.extend(sampleNow[9:sampleLen-1])

            else:
                sampleNow = df2[df2.redLightTime == curTime].values.tolist()
                sampleNow = sampleNow[0]  # 样本中有很多重复样本，因为我做了重采样。所以只用第一个
                tmp = sampleNow.copy()
                sampleNow.extend(sampleLast[9:sampleLen-1])
                sampleLast = tmp

            # print(iTime,sampleLast)
            # input()
            samplesAll.append(sampleNow)

filename = "../trainData/"+"france_0_allSamples1_2slot.csv"
samplesAll1 = pd.DataFrame(samplesAll)
samplesAll1.to_csv(filename, float_format='%.4f', index=0)

# !zip ../france_0_allSamples1_2slot.zip ../trainData/france_0_allSamples1_2slot.csv
